# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler , OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

# %%
pd.set_option('display.max_rows' , None)
pd.set_option('display.max_columns' , None)
pd.set_option('display.max_colWidth' , None)

# %%
df = pd.read_csv('gurgaon_properties_post_feature_selection_v2 (1).csv')

# %%
df.columns
# Out:
# Index(['property_type', 'sector', 'price', 'bedRoom', 'bathroom', 'balcony',
#        'agePossession', 'built_up_area', 'servant room', 'store room',
#        'furnishing_type', 'luxury_category', 'floor_category'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3554 entries, 0 to 3553
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_type    3554 non-null   object
#  1   sector           3554 non-null   object
#  2   price            3554 non-null   float64
#  3   bedRoom          3554 non-null   float64
#  4   bathroom         3554 non-null   float64
#  5   balcony          3554 non-null   object
#  6   agePossession    3554 non-null   object
#  7   built_up_area    3554 non-null   float64
#  8   servant room     3554 non-null   float64
#  9   store room       3554 non-null   float64
#  10  furnishing_type  3554 non-null   float64
#  11  luxury_category  3554 non-null   object
#  12  floor_category   3554 non-null   object
# dtypes: float64(7), object(6)
# memory usage: 361.1+ KB

# %%
df.head(2)
# Out:
#   property_type     sector  price  bedRoom  bathroom balcony agePossession  \
# 0          flat  sector 36   0.82      3.0       2.0       2  New Property
# 1          flat  sector 89   0.95      2.0       2.0       2  New Property
#
#    built_up_area  servant room  store room  furnishing_type luxury_category  \
# 0          850.0           0.0         0.0              0.0             Low
# 1         1226.0           1.0         0.0              0.0             Low
#
#   floor_category
# 0      Low Floor
# 1      Mid Floor

# %%
df.shape
# Out:
# (3554, 13)

# %%
df.isnull().sum()
# Out:
# property_type      0
# sector             0
# price              0
# bedRoom            0
# bathroom           0
# balcony            0
# agePossession      0
# built_up_area      0
# servant room       0
# store room         0
# furnishing_type    0
# luxury_category    0
# floor_category     0
# dtype: int64

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# 0.0    2349
# 1.0    1018
# 2.0     187
# Name: count, dtype: int64

# %%
df['furnishing_type'] = df['furnishing_type'].replace({0.0:'unfurnished' , 1.0:'semi-furnished' , 2.0:'furnished'})

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# unfurnished       2349
# semi-furnished    1018
# furnished          187
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony   agePossession  \
# 0          flat   sector 36   0.82      3.0       2.0       2    New Property
# 1          flat   sector 89   0.95      2.0       2.0       2    New Property
# 2          flat  sohna road   0.32      2.0       2.0       1    New Property
# 3          flat   sector 92   1.60      3.0       4.0      3+  Relatively New
# 4          flat  sector 102   0.48      2.0       2.0       1  Relatively New
#
#    built_up_area  servant room  store room furnishing_type luxury_category  \
# 0          850.0           0.0         0.0     unfurnished             Low
# 1         1226.0           1.0         0.0     unfurnished             Low
# 2         1000.0           0.0         0.0     unfurnished             Low
# 3         1615.0           1.0         0.0  semi-furnished            High
# 4          582.0           0.0         1.0     unfurnished            High
#
#   floor_category
# 0      Low Floor
# 1      Mid Floor
# 2     High Floor
# 3      Mid Floor
# 4      Mid Floor

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
y.isnull().sum()
# Out:
# np.int64(0)

# %%
# Applying the log1p transformation to the target variable
y_transformed = np.log1p(y)

# %%
y_transformed.sample(10)
# Out:
# 473     0.500775
# 721     0.717840
# 1907    1.386294
# 3313    1.360977
# 635     1.909543
# 530     0.576613
# 2348    1.321756
# 2058    0.810930
# 2708    0.883768
# 671     1.163151
# Name: price, dtype: float64

# %%
# Here we apply 3 types of encoading
# 1) -> Ordinal Encoading
# 2) -> One hot Encoading
# 3) -> Target Encoading

# %% [markdown]
# # **Ordinal Encoading**

# %%
columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode)
    ],
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean()
# Out:
# np.float64(0.7363096633436828)

# %%
scores.std()
# Out:
# np.float64(0.03238005754429932)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.946382216008936

# %%
def scorer(model_name, model):

    output = []

    output.append(model_name)

    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])

    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

    output.append(scores.mean())

    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

    pipeline.fit(X_train,y_train)

    y_pred = pipeline.predict(X_test)

    y_pred = np.expm1(y_pred)

    output.append(mean_absolute_error(np.expm1(y_test),y_pred))

    return output

# %%
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor

model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_output
# Out:
# [['linear_reg', np.float64(0.7363096633436828), 0.946382216008936],
#  ['svr', np.float64(0.7642021216646014), 0.8472636473483917],
#  ['ridge', np.float64(0.7363125343993554), 0.9463387741853388],
#  ['LASSO', np.float64(0.05943378064493573), 1.528905986892753],
#  ['decision tree', np.float64(0.7734845123987093), 0.7518664628678968],
#  ['random forest', np.float64(0.8801939105175908), 0.5251769207426612],
#  ['extra trees', np.float64(0.8680943845307171), 0.5528814162652566],
#  ['gradient boosting', np.float64(0.8725075923408557), 0.5768323401247935],
#  ['adaboost', np.float64(0.751762933601522), 0.8337056779083977],
#  ['mlp', np.float64(0.8081284885533782), 0.7060723090026295],
#  ['xgboost', np.float64(0.8894876835260124), 0.5040475127230885]]

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.889488  0.504048
# 5       random forest  0.880194  0.525177
# 6         extra trees  0.868094  0.552881
# 7   gradient boosting  0.872508  0.576832
# 9                 mlp  0.808128  0.706072
# 4       decision tree  0.773485  0.751866
# 8            adaboost  0.751763  0.833706
# 1                 svr  0.764202  0.847264
# 2               ridge  0.736313  0.946339
# 0          linear_reg  0.736310  0.946382
# 3               LASSO  0.059434  1.528906

# %% [markdown]
# **Ovserbation**
# - best r2score = 0.88
# - best mae = 0.50
# - best algo = Xgboost

# %% [markdown]
# # **OneHotEncoading**

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first' , handle_unknown='ignore'),['sector','agePossession','furnishing_type'])
    ],
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean()
# Out:
# np.float64(0.8546112792716141)

# %%
scores.std()
# Out:
# np.float64(0.01599323234861558)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['sector', 'agePossession',
#                                                    'furnishing_type'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)
y_pred = np.expm1(y_pred)
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.6497696680344619

# %%
def scorer(model_name, model):

    output = []

    output.append(model_name)

    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])

    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

    output.append(scores.mean())

    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

    pipeline.fit(X_train,y_train)

    y_pred = pipeline.predict(X_test)

    y_pred = np.expm1(y_pred)

    output.append(mean_absolute_error(np.expm1(y_test),y_pred))

    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 6         extra trees  0.894769  0.472960
# 10            xgboost  0.895850  0.493456
# 5       random forest  0.890522  0.497932
# 7   gradient boosting  0.876331  0.570392
# 9                 mlp  0.874152  0.585037
# 0          linear_reg  0.854611  0.649770
# 2               ridge  0.854676  0.652899
# 4       decision tree  0.808560  0.696767
# 8            adaboost  0.755810  0.833800
# 1                 svr  0.769752  0.834124
# 3               LASSO  0.059434  1.528906

# %% [markdown]
# **Observation**
# - best model -> Extra Trees
# - best mae -> 0.472
# - best r2Score -> 0.8947
#
# - mae is reduced from 0.49 to 0.47

# %% [markdown]
# #**OneHotEncoding With PCA**

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False, handle_unknown='ignore'),['sector','agePossession'])
    ],
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', PCA(n_components=0.95)),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean()
# Out:
# np.float64(0.06225201431451134)

# %%
scores.std()
# Out:
# np.float64(0.019860594071640165)

# %%
def scorer(model_name, model):

    output = []

    output.append(model_name)

    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('pca', PCA(n_components=0.95)),
        ('regressor', model)
    ])

    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

    output.append(scores.mean())

    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

    pipeline.fit(X_train,y_train)

    y_pred = pipeline.predict(X_test)

    y_pred = np.expm1(y_pred)

    output.append(mean_absolute_error(np.expm1(y_test),y_pred))

    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 5       random forest  0.762281  0.653861
# 6         extra trees  0.738719  0.696616
# 4       decision tree  0.696442  0.761509
# 10            xgboost  0.622205  0.967581
# 7   gradient boosting  0.610623  0.987906
# 8            adaboost  0.303943  1.345162
# 1                 svr  0.218073  1.361198
# 9                 mlp  0.213619  1.407659
# 2               ridge  0.062252  1.526707
# 0          linear_reg  0.062252  1.526707
# 3               LASSO  0.059676  1.528739

# %% [markdown]
# **Observation**
# - result are become down from previous one

# %% [markdown]
# # **TargetEncoading**

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.11/dist-packages (2.8.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (1.0.1)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (1.15.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from category_encoders) (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.9.0->category_encoders) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)

# %%
import category_encoders as ce

columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['agePossession']),
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ],
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (np.float64(0.829521918225536), np.float64(0.018384463379122903))

# %%
def scorer(model_name, model):

    output = []

    output.append(model_name)

    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])

    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

    output.append(scores.mean())

    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

    pipeline.fit(X_train,y_train)

    y_pred = pipeline.predict(X_test)

    y_pred = np.expm1(y_pred)

    output.append(mean_absolute_error(np.expm1(y_test),y_pred))

    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.904798  0.447518
# 6         extra trees  0.901049  0.456096
# 5       random forest  0.902099  0.462697
# 7   gradient boosting  0.888941  0.508015
# 4       decision tree  0.833127  0.555694
# 9                 mlp  0.852458  0.610238
# 0          linear_reg  0.829522  0.713011
# 2               ridge  0.829536  0.713523
# 8            adaboost  0.819194  0.717070
# 1                 svr  0.782917  0.818851
# 3               LASSO  0.059434  1.528906

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'regressor__n_estimators': [50, 100, 200, 300],
    'regressor__max_depth': [None, 10, 20, 30],
    'regressor__max_samples':[0.1, 0.25, 0.5, 1.0],
    'regressor__max_features': ['auto', 'sqrt']
}

# %%
columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['agePossession']),
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ],
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
search = GridSearchCV(pipeline, param_grid, cv=kfold, scoring='r2', n_jobs=-1, verbose=4)

# %%
search.fit(X, y_transformed)
# Out:
# Fitting 10 folds for each of 128 candidates, totalling 1280 fits
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 640 fits failed out of a total of 1280.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 640 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 662, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['bedRoom',
#                                                                           'bathroom',
#                                                                           'built_up_area',
#                                                                           'servant '
#                                                                           'room',
#                                                                           'store '
#                                                                           'room']),
#                                                                         ('cat',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['property_type',
#                                                                           's...
#                                                                          OneHotEncoder(drop='first',
#                                                                                        sparse_output=False),
#                                                                          ['agePossession']),
#                                                                         ('target_enc',
#                                                                          TargetEncoder(),
#                                                                          ['sector'])])),
#                                        ('regressor', RandomForestRegressor())]),
#              n_jobs=-1,
#              param_grid={'regressor__max_depth': [None, 10, 20, 30],
#                          'regressor__max_features': ['auto', 'sqrt'],
#                          'regressor__max_samples': [0.1, 0.25, 0.5, 1.0],
#                          'regressor__n_estimators': [50, 100, 200, 300]},
#              scoring='r2', verbose=4)

# %%
final_pipe = search.best_estimator_

# %%
search.best_params_
# Out:
# {'regressor__max_depth': 20,
#  'regressor__max_features': 'sqrt',
#  'regressor__max_samples': 1.0,
#  'regressor__n_estimators': 100}

# %%
search.best_score_
# Out:
# np.float64(0.9032284535081097)

# %%
final_pipe.fit(X,y_transformed)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['agePossession']),
#                                                  ('target_enc', TargetEncoder(),
#                                                   ['sector'])])),
#                 ('regressor',
#                  RandomForestRegressor(max_depth=20, max_features='sqrt',
#                                        max_samples=1.0))])

# %% [markdown]
# # **Exporting The Model**

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['sector','agePossession'])
    ],
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(n_estimators=500))
])

# %%
pipeline.fit(X,y_transformed)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['sector',
#                                                    'agePossession'])])),
#                 ('regressor', RandomForestRegressor(n_estimators=500))])

# %%
import pickle

with open('pipeline.pkl', 'wb') as file:
    pickle.dump(pipeline, file)

# %%
with open('df.pkl', 'wb') as file:
    pickle.dump(X, file)

# %%
X
# Out:
#      property_type             sector  bedRoom  bathroom balcony  \
# 0             flat          sector 36      3.0       2.0       2
# 1             flat          sector 89      2.0       2.0       2
# 2             flat         sohna road      2.0       2.0       1
# 3             flat          sector 92      3.0       4.0      3+
# 4             flat         sector 102      2.0       2.0       1
# 5             flat        gwal pahari      4.0       4.0      3+
# 6             flat         sector 108      3.0       3.0      3+
# 7             flat         sector 102      3.0       4.0       3
# 8            house         sector 105      3.0       2.0       1
# 9            house          sector 26      3.0       3.0       2
# 10           house         sector 109      3.0       2.0       0
# 11            flat          sector 28      2.0       2.0       2
# 12            flat         sector 109      3.0       4.0       3
# 13            flat          sector 65      4.0       4.0      3+
# 14           house          sector 12      2.0       4.0       2
# 15            flat          sector 92      3.0       4.0       3
# 16            flat          sector 85      2.0       2.0       3
# 17            flat         sector 70a      2.0       2.0       3
# 18            flat          sector 85      3.0       4.0      3+
# 19            flat          sector 30      2.0       2.0       1
# 20            flat         sector 107      2.0       2.0      3+
# 21            flat           sector 3      2.0       2.0       3
# 22            flat           sector 2      1.0       1.0       1
# 23           house          sector 41      8.0       5.0      3+
# 24           house          sector 41      7.0       7.0      3+
# 25            flat          sector 28      4.0       2.0      3+
# 26           house           sector 4      1.0       1.0       0
# 27           house         sector 109      4.0       4.0      3+
# 28            flat          sector 62      2.0       2.0       3
# 29           house          sector 49      6.0       6.0       3
# 30            flat          sector 81      2.0       2.0       3
# 31            flat          sector 65      3.0       3.0       3
# 32            flat          sector 66      3.0       3.0       3
# 33           house          sector 89      2.0       2.0       2
# 34            flat          sector 86      3.0       3.0      3+
# 35           house          sector 48      4.0       4.0      3+
# 36           house         sector 109      5.0       6.0      3+
# 37            flat          sector 51      4.0       4.0       3
# 38            flat          sector 37      3.0       3.0       3
# 39            flat         sector 111      2.0       2.0       2
# 40            flat          sector 67      3.0       3.0       3
# 41           house          sector 28      4.0       3.0       3
# 42            flat         sector 111      3.0       4.0       2
# 43            flat         sector 113      3.0       3.0      3+
# 44           house          sector 13      3.0       6.0       2
# 45            flat          sector 61      3.0       2.0       3
# 46            flat         sector 113      3.0       3.0       3
# 47            flat          sector 69      3.0       3.0       1
# 48            flat          sector 89      3.0       2.0       0
# 49            flat         sector 67a      3.0       4.0       3
# 50            flat         sector 37d      2.0       2.0       3
# 51            flat          sector 82      2.0       2.0       2
# 52            flat          sector 53      3.0       3.0      3+
# 53            flat          sector 74      2.0       2.0       3
# 54            flat         sector 37d      3.0       3.0       3
# 55            flat         sector 108      3.0       4.0       3
# 56            flat          sector 52      1.0       1.0       0
# 57            flat          sector 12      2.0       2.0       1
# 58           house          sector 43      4.0       4.0       2
# 59            flat          sector 85      2.0       2.0       3
# 60            flat          sector 36      2.0       2.0       2
# 61            flat          sector 89      1.0       1.0       1
# 62           house           sector 4      3.0       2.0       1
# 63            flat           sector 2      1.0       1.0       2
# 64            flat         sector 70a      3.0       4.0      3+
# 65           house          sector 14      5.0       4.0       2
# 66            flat          sector 67      3.0       4.0       3
# 67            flat          sector 81      3.0       3.0      3+
# 68           house          sector 25      2.0       9.0       3
# 69            flat          sector 95      2.0       2.0       1
# 70            flat         sector 102      1.0       1.0       2
# 71           house          sector 56      4.0       4.0       2
# 72            flat         sector 109      3.0       4.0      3+
# 73           house          sector 41      3.0       3.0       3
# 74           house           sector 3      7.0       2.0       0
# 75            flat          sector 86      3.0       3.0       1
# 76            flat          sector 48      4.0       4.0      3+
# 77            flat          sector 83      2.0       2.0       3
# 78            flat         sector 107      3.0       2.0       2
# 79            flat         sector 104      3.0       2.0       2
# 80            flat         sector 88a      2.0       2.0       3
# 81            flat         sohna road      3.0       3.0      3+
# 82            flat          sector 85      3.0       3.0       2
# 83           house         sector 105      2.0       2.0       0
# 84            flat          sector 83      3.0       3.0       2
# 85            flat          sector 69      3.0       3.0       2
# 86            flat         sector 102      2.0       2.0       3
# 87           house          sector 55      4.0       4.0       0
# 88           house          sector 50      5.0       7.0      3+
# 89            flat          sector 84      2.0       2.0       1
# 90            flat          sector 84      2.0       2.0       0
# 91           house           sector 4      3.0       4.0       1
# 92            flat         sohna road      2.0       2.0       2
# 93            flat          sector 91      4.0       3.0      3+
# 94            flat          sector 49      3.0       3.0       3
# 95            flat          sector 48      3.0       3.0      3+
# 96            flat         sohna road      2.0       2.0      3+
# 97            flat          sector 69      3.0       3.0       1
# 98           house          sector 76      2.0       2.0       2
# 99            flat         sector 82a      3.0       3.0      3+
# 100           flat          sector 78      2.0       2.0       2
# 101           flat          sector 95      2.0       2.0       1
# 102           flat            manesar      3.0       3.0       2
# 103           flat          sector 93      4.0       4.0       3
# 104           flat           sector 7      2.0       2.0       1
# 105           flat          sector 71      2.0       2.0       2
# 106          house          sector 25      5.0       5.0      3+
# 107           flat          sector 56      3.0       3.0      3+
# 108           flat         sector 110      3.0       3.0       3
# 109           flat          sector 67      3.0       4.0      3+
# 110           flat         sector 107      3.0       2.0       2
# 111           flat          sector 69      3.0       3.0       2
# 112           flat         sector 113      4.0       4.0      3+
# 113           flat         sector 104      1.0       2.0       2
# 114           flat          sector 33      2.0       2.0      3+
# 115           flat         sector 113      2.0       2.0       0
# 116          house           sector 4      3.0       3.0       2
# 117           flat         sector 88a      3.0       2.0       2
# 118           flat          sector 41      4.0       4.0       3
# 119           flat         sector 102      4.0       4.0      3+
# 120           flat          sector 49      3.0       3.0       2
# 121           flat          sector 61      3.0       3.0       2
# 122           flat          sector 82      2.0       2.0      3+
# 123           flat          sector 37      3.0       3.0      3+
# 124           flat          sector 70      3.0       3.0       2
# 125          house         sector 104      3.0       5.0      3+
# 126           flat          sector 70      3.0       5.0       0
# 127           flat         sector 103      4.0       4.0       3
# 128          house          sector 82      3.0       3.0      3+
# 129          house          sector 28      2.0       2.0       0
# 130           flat          sector 89      3.0       3.0       2
# 131          house         sector 109      4.0       4.0      3+
# 132           flat         sector 37d      2.0       2.0       3
# 133           flat         sohna road      3.0       2.0       2
# 134           flat         sector 107      2.0       2.0       3
# 135           flat          sector 66      3.0       4.0       3
# 136           flat          sector 90      4.0       4.0      3+
# 137           flat          sector 43      3.0       2.0       3
# 138          house          sector 38      6.0       6.0      3+
# 139          house           sector 3      2.0       2.0       1
# 140           flat         sector 37d      4.0       4.0       3
# 141           flat          sector 90      2.0       2.0       3
# 142           flat          sector 65      3.0       4.0       3
# 143           flat          sector 90      4.0       4.0      3+
# 144          house          sector 51      6.0       3.0      3+
# 145          house          sector 33      5.0       6.0       3
# 146           flat         sector 102      2.0       2.0       3
# 147           flat          sector 79      3.0       3.0       0
# 148           flat          sector 83      2.0       2.0       3
# 149           flat          sector 14      3.0       4.0      3+
# 150           flat          sector 86      3.0       3.0       1
# 151          house         sector 103      4.0       4.0      3+
# 152           flat          sector 69      3.0       3.0       1
# 153           flat          sector 71      3.0       4.0       3
# 154           flat         sector 82a      3.0       3.0      3+
# 155           flat         sector 88a      3.0       3.0       3
# 156           flat          sector 81      3.0       3.0      3+
# 157           flat          sector 90      4.0       4.0      3+
# 158           flat          sector 90      3.0       3.0      3+
# 159           flat          sector 90      3.0       3.0       3
# 160           flat           sector 2      2.0       2.0       3
# 161           flat         sector 108      2.0       3.0       3
# 162           flat          sector 61      3.0       3.0       2
# 163           flat          sector 56      3.0       3.0       3
# 164           flat          sector 79      2.0       2.0      3+
# 165           flat         sector 113      3.0       3.0       2
# 166           flat         sector 104      4.0       4.0      3+
# 167          house         sector 112      4.0       4.0      3+
# 168           flat          sector 22      4.0       6.0      3+
# 169           flat         sector 108      2.0       2.0       3
# 170           flat         sector 102      2.0       2.0       2
# 171           flat          sector 92      3.0       4.0       2
# 172          house          sector 26      3.0       3.0       3
# 173           flat          sector 90      3.0       3.0      3+
# 174           flat          sector 70      3.0       5.0       3
# 175          house          sector 13      2.0       7.0       3
# 176           flat          sector 84      2.0       2.0      3+
# 177           flat          sector 85      2.0       2.0       3
# 178           flat          sector 92      3.0       4.0       3
# 179           flat          sector 49      3.0       3.0       3
# 180           flat          sector 67      4.0       4.0      3+
# 181          house          sector 33      5.0       5.0      3+
# 182           flat         sector 107      2.0       2.0       1
# 183           flat            manesar      4.0       4.0       3
# 184           flat          sector 52      5.0       7.0      3+
# 185           flat          sector 76      3.0       3.0       2
# 186           flat          sector 84      3.0       3.0       3
# 187           flat          sector 33      3.0       3.0       3
# 188           flat          sector 95      2.0       2.0       2
# 189           flat        gwal pahari      2.0       2.0       2
# 190           flat         sector 102      3.0       4.0      3+
# 191           flat         sohna road      2.0       2.0       3
# 192           flat            manesar      3.0       3.0      3+
# 193           flat          sector 70      3.0       3.0       2
# 194           flat          sector 59      3.0       3.0       3
# 195           flat         sector 102      3.0       3.0       3
# 196           flat         sector 109      3.0       3.0      3+
# 197           flat          sector 95      2.0       2.0       0
# 198           flat          sector 86      2.0       2.0       1
# 199           flat          sector 99      2.0       2.0       1
# 200           flat          sector 95      3.0       2.0       2
# 201           flat          sector 56      4.0       4.0       3
# 202           flat          sector 92      4.0       4.0       2
# 203           flat          sector 86      3.0       4.0       3
# 204          house          sector 12      3.0       3.0       0
# 205           flat          sector 65      4.0       4.0       3
# 206           flat           sector 9      3.0       3.0       2
# 207           flat          sector 91      3.0       3.0      3+
# 208           flat          sector 65      3.0       3.0       3
# 209           flat          sector 81      2.0       2.0       3
# 210           flat          sector 81      4.0       5.0      3+
# 211           flat          sector 92      3.0       3.0       1
# 212           flat          sector 69      4.0       5.0      3+
# 213           flat          sector 58      4.0       5.0       3
# 214           flat          sector 77      3.0       3.0       3
# 215           flat          sector 99      3.0       5.0       3
# 216           flat          sector 81      3.0       4.0      3+
# 217           flat         sohna road      1.0       1.0       1
# 218           flat          sector 95      2.0       2.0       2
# 219          house           sector 1      4.0       3.0       2
# 220           flat           sector 2      2.0       2.0       3
# 221           flat         sector 109      3.0       3.0       1
# 222           flat         sector 110      4.0       4.0       3
# 223           flat         sohna road      2.0       2.0       2
# 224           flat         sector 82a      1.0       1.0       0
# 225           flat          sector 90      3.0       3.0      3+
# 226           flat          sector 83      3.0       3.0       2
# 227          house          sector 57      5.0       4.0      3+
# 228           flat          sector 71      3.0       3.0       3
# 229           flat         sector 102      3.0       3.0      3+
# 230           flat          sector 65      3.0       3.0       3
# 231           flat          sector 65      3.0       3.0       3
# 232           flat          sector 33      3.0       3.0       3
# 233           flat         sector 106      4.0       6.0      3+
# 234           flat           sector 9      3.0       3.0       2
# 235           flat         sector 109      3.0       4.0       3
# 236           flat          sector 48      3.0       3.0       1
# 237          house          sector 25      5.0       5.0       3
# 238           flat         sector 105      3.0       2.0       1
# 239           flat          sector 61      3.0       3.0       2
# 240           flat         sector 109      3.0       4.0      3+
# 241           flat          sector 65      4.0       3.0       2
# 242          house          sector 49      2.0       6.0       3
# 243           flat         sector 113      4.0       4.0      3+
# 244           flat          sector 33      3.0       3.0      3+
# 245           flat         sector 82a      3.0       3.0       3
# 246           flat  dwarka expressway      3.0       3.0       2
# 247           flat          sector 90      3.0       3.0       2
# 248           flat          sector 65      2.0       2.0       3
# 249          house           sector 9      2.0       3.0       0
# 250           flat          sector 43      3.0       3.0      3+
# 251           flat          sector 65      4.0       4.0      3+
# 252           flat          sector 63      4.0       4.0       0
# 253           flat           sector 2      3.0       4.0      3+
# 254          house          sector 76      4.0       4.0       0
# 255           flat          sector 61      3.0       3.0       3
# 256           flat         sector 102      3.0       3.0       3
# 257           flat         sector 106      3.0       4.0      3+
# 258           flat          sector 14      4.0       4.0       0
# 259           flat          sector 95      2.0       2.0       2
# 260          house          sector 57      6.0       6.0       2
# 261           flat         sector 109      3.0       2.0       2
# 262           flat         sector 107      2.0       2.0       3
# 263          house          sector 56      8.0       8.0      3+
# 264           flat          sector 70      3.0       4.0      3+
# 265          house          sector 48      3.0       6.0       2
# 266           flat          sector 69      3.0       3.0       1
# 267          house          sector 69      1.0       1.0       0
# 268           flat          sector 89      2.0       2.0       2
# 269           flat          sector 52      3.0       3.0       3
# 270           flat          sector 78      2.0       2.0       1
# 271           flat          sector 99      3.0       3.0       0
# 272           flat         sohna road      2.0       1.0       3
# 273           flat         sector 37d      2.0       2.0       3
# 274           flat          sector 65      2.0       2.0       2
# 275           flat          sector 99      3.0       5.0       3
# 276           flat         sector 112      4.0       5.0      3+
# 277           flat          sector 89      2.0       2.0       3
# 278           flat          sector 79      2.0       2.0       3
# 279           flat          sector 89      2.0       2.0       2
# 280          house          sector 57      2.0       8.0      3+
# 281           flat          sector 92      3.0       3.0       2
# 282           flat         sector 37d      3.0       3.0       3
# 283          house         sector 109      7.0       5.0      3+
# 284           flat         sector 37d      3.0       3.0      3+
# 285           flat         sector 110      2.0       1.0       1
# 286           flat         sector 102      2.0       2.0       3
# 287          house          sector 28     10.0      10.0      3+
# 288           flat          sector 53      3.0       4.0      3+
# 289           flat         sector 104      4.0       5.0      3+
# 290           flat          sector 53      3.0       4.0       3
# 291          house           sector 5      1.0       1.0       0
# 292           flat          sector 92      3.0       3.0       3
# 293           flat          sector 69      2.0       2.0       2
# 294          house           sector 7      1.0       1.0       1
# 295          house          sector 40      9.0       9.0      3+
# 296           flat          sector 78      3.0       4.0       3
# 297           flat          sector 66      3.0       4.0       2
# 298           flat          sector 65      3.0       3.0       3
# 299           flat          sector 90      4.0       4.0      3+
# 300           flat          sector 83      3.0       3.0       3
# 301           flat          sector 61      2.0       2.0       2
# 302           flat          sector 53      4.0       5.0      3+
# 303          house          sector 26      4.0       4.0      3+
# 304           flat          sector 33      2.0       2.0       2
# 305          house           sector 5      6.0       1.0       0
# 306           flat          sector 92      3.0       2.0       2
# 307           flat         sector 102      3.0       3.0      3+
# 308          house         sohna road      3.0       2.0       2
# 309          house          sector 12      9.0       9.0      3+
# 310          house          sector 14      4.0       4.0      3+
# 311           flat          sector 92      4.0       4.0       3
# 312           flat         sector 106      3.0       3.0       3
# 313           flat           sector 9      4.0       3.0       2
# 314           flat         sohna road      2.0       2.0       2
# 315          house          sector 23      5.0       5.0       2
# 316           flat          sector 74      3.0       3.0       3
# 317           flat          sector 92      3.0       3.0       0
# 318          house           sector 6      6.0       4.0       0
# 319          house          sector 53      5.0       5.0       2
# 320          house           sector 3      4.0       2.0       2
# 321           flat         sohna road      2.0       2.0       2
# 322          house          sector 28      4.0       4.0       0
# 323           flat         sector 104      2.0       2.0       3
# 324          house          sector 72      5.0       5.0      3+
# 325           flat          sector 99      2.0       2.0       1
# 326           flat          sector 66      4.0       4.0       3
# 327           flat          sector 47      2.0       2.0       2
# 328          house          sector 50      3.0       3.0       3
# 329          house          sector 38      3.0       9.0      3+
# 330           flat         sector 37d      2.0       2.0       3
# 331           flat         sector 109      3.0       3.0       3
# 332           flat          sector 77      3.0       3.0      3+
# 333           flat          sector 43      3.0       3.0       2
# 334           flat         sector 104      3.0       3.0      3+
# 335           flat          sector 84      4.0       4.0       3
# 336          house          sector 45      5.0       4.0       2
# 337           flat          sector 70      2.0       2.0       2
# 338           flat          sector 71      1.0       1.0       0
# 339           flat          sector 33      4.0       4.0      3+
# 340          house           sector 5      4.0       3.0       2
# 341           flat          sector 95      2.0       2.0       0
# 342           flat          sector 83      5.0       7.0      3+
# 343           flat         sector 103      1.0       1.0       1
# 344           flat          sector 65      3.0       3.0       3
# 345           flat          sector 84      3.0       3.0       3
# 346           flat          sector 81      2.0       2.0       3
# 347          house          sector 33      2.0       2.0       2
# 348          house          sector 14      6.0       6.0      3+
# 349           flat          sector 68      2.0       2.0       3
# 350           flat          sector 69      3.0       3.0       1
# 351           flat         sector 113      4.0       4.0      3+
# 352           flat          sector 48      3.0       3.0       3
# 353          house          sector 43      3.0       3.0       2
# 354           flat          sector 63      4.0       4.0       0
# 355           flat         sector 108      2.0       2.0       2
# 356           flat          sector 84      4.0       4.0      3+
# 357           flat          sector 84      3.0       3.0       3
# 358           flat         sector 102      2.0       2.0       2
# 359           flat         sector 37d      3.0       3.0       3
# 360          house           sector 3      5.0       3.0       0
# 361           flat          sector 92      3.0       3.0       3
# 362           flat          sector 25      4.0       4.0       3
# 363           flat         sohna road      2.0       2.0       3
# 364           flat          sector 72      3.0       3.0       3
# 365           flat          sector 81      3.0       4.0      3+
# 366          house          sector 11      5.0       4.0       1
# 367           flat          sector 70      3.0       3.0      3+
# 368           flat          sector 37      3.0       5.0      3+
# 369          house          sector 56      2.0       2.0       0
# 370           flat          sector 84      2.0       2.0      3+
# 371           flat          sector 82      2.0       2.0       2
# 372           flat          sector 95      2.0       2.0       2
# 373          house          sector 14      5.0       5.0       0
# 374          house           sector 2      3.0       7.0      3+
# 375           flat          sector 95      2.0       2.0       2
# 376           flat          sector 92      3.0       3.0       2
# 377          house          sector 22      7.0       5.0      3+
# 378          house         sector 109      4.0       4.0      3+
# 379           flat          sector 60      2.0       2.0       2
# 380           flat          sector 86      3.0       3.0       3
# 381          house          sector 25      4.0       4.0      3+
# 382           flat          sector 66      2.0       2.0       2
# 383           flat         sector 108      3.0       3.0       2
# 384          house          sector 28      5.0       6.0      3+
# 385           flat          sector 92      4.0       4.0       3
# 386           flat          sector 22      3.0       3.0       3
# 387           flat          sector 36      3.0       2.0       3
# 388          house          sector 48      7.0       7.0      3+
# 389           flat          sector 39      4.0       3.0       3
# 390           flat          sector 77      2.0       2.0       2
# 391           flat          sector 60      2.0       3.0       2
# 392          house          sector 26      5.0       5.0      3+
# 393           flat         sohna road      2.0       2.0       2
# 394           flat          sector 70      4.0       4.0      3+
# 395           flat          sector 85      2.0       2.0       3
# 396          house          sector 25      3.0       2.0       3
# 397           flat          sector 65      3.0       3.0       3
# 398           flat          sector 83      2.0       2.0       2
# 399           flat          sector 84      2.0       2.0       3
# 400          house          sector 72      5.0       5.0      3+
# 401           flat          sector 91      4.0       4.0      3+
# 402           flat          sector 70      3.0       5.0       3
# 403           flat           sector 9      3.0       3.0       2
# 404           flat         sector 108      4.0       4.0      3+
# 405          house          sector 81      1.0       1.0       0
# 406          house          sector 26      7.0       9.0      3+
# 407           flat          sector 85      4.0       4.0       3
# 408           flat          sector 92      3.0       2.0       3
# 409           flat         sector 63a      2.0       2.0       2
# 410          house          sector 25      5.0       5.0       2
# 411          house          sector 25      5.0       6.0       3
# 412           flat         sector 102      3.0       4.0      3+
# 413           flat         sohna road      2.0       2.0       2
# 414           flat          sector 86      3.0       2.0       2
# 415           flat         sector 108      3.0       4.0       2
# 416           flat         sohna road      2.0       2.0       2
# 417           flat          sector 86      3.0       3.0       2
# 418           flat          sector 71      1.0       1.0       2
# 419          house          sector 24      4.0       4.0       2
# 420           flat          sector 92      4.0       4.0       3
# 421          house          sector 56      4.0       4.0      3+
# 422           flat          sector 50      4.0       4.0       3
# 423           flat         sector 109      3.0       3.0      3+
# 424           flat          sector 83      2.0       2.0       2
# 425           flat         sector 70a      2.0       2.0       3
# 426           flat         sector 37d      3.0       3.0      3+
# 427           flat        gwal pahari      3.0       3.0       3
# 428           flat          sector 85      3.0       4.0      3+
# 429          house           sector 2      4.0       3.0       2
# 430           flat         sector 110      5.0       5.0       2
# 431           flat          sector 85      4.0       4.0       3
# 432           flat          sector 12      3.0       3.0       1
# 433          house          sector 66      5.0       6.0      3+
# 434           flat          sector 85      4.0       4.0      3+
# 435          house          sector 11      4.0       3.0       2
# 436           flat         sector 109      3.0       3.0      3+
# 437           flat          sector 37      2.0       3.0       3
# 438           flat          sector 69      3.0       3.0       1
# 439           flat         sector 70a      2.0       2.0       3
# 440           flat         sector 37d      3.0       2.0       3
# 441           flat          sector 85      4.0       4.0       3
# 442           flat          sector 60      3.0       3.0       3
# 443           flat         sector 106      5.0       6.0      3+
# 444           flat          sector 67      4.0       4.0      3+
# 445           flat          sector 57      3.0       3.0       3
# 446           flat          sector 67      3.0       3.0       3
# 447           flat         sector 102      2.0       2.0       1
# 448          house         sohna road      2.0       2.0       1
# 449           flat         sector 103      1.0       2.0       2
# 450           flat         sector 111      1.0       1.0       1
# 451           flat          sector 69      4.0       4.0       1
# 452          house          sector 91      4.0       4.0       3
# 453           flat          sector 28      3.0       4.0       3
# 454           flat          sector 69      3.0       3.0       2
# 455           flat          sector 71      3.0       4.0       3
# 456           flat         sector 37d      3.0       3.0       3
# 457           flat          sector 81      2.0       2.0       2
# 458          house          sector 66      5.0       6.0      3+
# 459           flat          sector 28      3.0       3.0       3
# 460          house         sector 70a      4.0       5.0      3+
# 461           flat          sector 50      3.0       3.0       3
# 462           flat          sector 48      4.0       4.0      3+
# 463           flat          sector 53      4.0       4.0       3
# 464           flat          sector 89      2.0       2.0       2
# 465           flat          sector 71      4.0       4.0       3
# 466           flat         sector 107      3.0       4.0       0
# 467           flat          sector 70      3.0       5.0       3
# 468           flat         sohna road      2.0       2.0       3
# 469           flat          sector 79      3.0       4.0      3+
# 470           flat          sector 33      3.0       2.0       2
# 471           flat          sector 85      3.0       4.0       3
# 472           flat         sector 107      2.0       2.0       2
# 473           flat         sector 104      3.0       2.0       2
# 474          house           sector 1      6.0       7.0       0
# 475           flat          sector 36      3.0       4.0       3
# 476           flat          sector 12      3.0       3.0       2
# 477           flat          sector 90      2.0       2.0       3
# 478           flat          sector 86      2.0       2.0       3
# 479           flat          sector 43      4.0       5.0       3
# 480           flat          sector 99      4.0       4.0      3+
# 481           flat          sector 99      2.0       2.0       2
# 482          house          sector 55      3.0       3.0      3+
# 483           flat          sector 33      3.0       3.0       2
# 484           flat         sohna road      2.0       2.0       0
# 485           flat         sector 104      3.0       2.0      3+
# 486           flat          sector 67      4.0       4.0      3+
# 487          house          sector 14      6.0       4.0       2
# 488           flat          sector 56      3.0       4.0       3
# 489           flat          sector 89      3.0       1.0       0
# 490           flat          sector 92      4.0       4.0       3
# 491           flat          sector 81      2.0       2.0       1
# 492           flat         sector 108      2.0       3.0       3
# 493          house          sector 25     10.0      10.0       3
# 494           flat         sector 109      3.0       3.0       2
# 495           flat           sector 2      3.0       3.0      3+
# 496           flat          sector 37      3.0       3.0       0
# 497           flat         sector 107      2.0       2.0       1
# 498          house          sector 22      6.0       6.0      3+
# 499           flat         sector 103      4.0       6.0      3+
# 500          house           sector 4      4.0       2.0       2
# 501           flat          sector 33      2.0       2.0       3
# 502          house         sector 109      5.0       5.0       2
# 503          house          sector 24      8.0       5.0      3+
# 504           flat         sohna road      2.0       2.0       2
# 505          house          sector 66      5.0       6.0      3+
# 506           flat          sector 90      3.0       3.0       2
# 507           flat          sector 84      3.0       3.0       3
# 508          house           sector 5      2.0       4.0       2
# 509           flat          sector 99      2.0       1.0       2
# 510           flat          sector 89      2.0       3.0       3
# 511           flat          sector 37      3.0       3.0       3
# 512           flat         sector 113      4.0       5.0      3+
# 513           flat          sector 81      3.0       4.0      3+
# 514           flat          sector 83      3.0       3.0       3
# 515           flat          sector 82      2.0       2.0       2
# 516           flat         sector 102      3.0       3.0      3+
# 517           flat         sector 112      3.0       5.0      3+
# 518          house          sector 45      3.0       9.0      3+
# 519           flat          sector 74      2.0       2.0      3+
# 520           flat           sector 3      2.0       2.0       2
# 521          house          sector 46      6.0       6.0      3+
# 522           flat          sector 69      4.0       4.0       2
# 523          house          sector 24      8.0      10.0      3+
# 524           flat         sector 70a      4.0       4.0       3
# 525           flat          sector 47      3.0       4.0      3+
# 526           flat         sohna road      2.0       2.0       2
# 527           flat         sector 109      3.0       3.0       3
# 528          house          sector 66      5.0       6.0      3+
# 529           flat          sector 92      3.0       3.0       2
# 530           flat          sector 82      2.0       2.0       2
# 531           flat          sector 59      4.0       4.0      3+
# 532           flat           sector 7      3.0       2.0       1
# 533           flat          sector 84      2.0       2.0       3
# 534           flat         sector 37d      3.0       3.0       3
# 535           flat          sector 70      3.0       4.0       2
# 536           flat          sector 50      3.0       3.0       2
# 537           flat          sector 69      4.0       4.0       1
# 538          house         sector 37d      1.0       1.0       0
# 539           flat          sector 65      4.0       4.0       3
# 540           flat          sector 86      3.0       4.0      3+
# 541           flat            manesar      3.0       3.0      3+
# 542          house          sector 50      3.0       3.0       2
# 543          house          sector 17      2.0       5.0       3
# 544           flat         sector 37d      3.0       3.0      3+
# 545           flat           sector 4      2.0       2.0       1
# 546          house           sector 2      3.0       3.0       3
# 547           flat          sector 15      3.0       3.0      3+
# 548           flat         sector 63a      3.0       2.0       2
# 549           flat         sector 110      4.0       5.0       3
# 550           flat         sector 109      3.0       4.0      3+
# 551           flat          sector 86      3.0       2.0       1
# 552           flat         sector 37d      4.0       3.0       3
# 553          house           sector 4      3.0       2.0       1
# 554          house          sector 26      3.0       3.0       3
# 555           flat         sector 102      3.0       4.0      3+
# 556          house         sector 70a      3.0       3.0      3+
# 557           flat          sector 89      2.0       2.0       2
# 558           flat          sector 81      4.0       6.0      3+
# 559           flat         sector 107      2.0       2.0      3+
# 560           flat         sector 70a      2.0       2.0       2
# 561           flat          sector 62      4.0       6.0       3
# 562           flat         sector 37d      2.0       2.0       3
# 563           flat          sector 86      2.0       2.0       1
# 564           flat          sector 49      3.0       3.0       3
# 565           flat         sohna road      2.0       2.0       2
# 566           flat          sector 79      2.0       2.0       2
# 567           flat          sector 70      4.0       5.0      3+
# 568           flat         sohna road      2.0       2.0       2
# 569           flat          sector 81      2.0       2.0       2
# 570           flat          sector 56      3.0       4.0      3+
# 571           flat          sector 10      2.0       2.0       3
# 572           flat          sector 82      4.0       4.0      3+
# 573           flat          sector 79      3.0       3.0       3
# 574           flat          sector 22      2.0       2.0       2
# 575           flat           sector 2      2.0       2.0       3
# 576           flat          sector 55      3.0       3.0       2
# 577           flat          sector 92      3.0       3.0       1
# 578           flat          sector 70      2.0       2.0       3
# 579           flat          sector 49      3.0       3.0       3
# 580           flat         sector 109      3.0       3.0      3+
# 581          house          sector 57      5.0       5.0      3+
# 582          house          sector 25      5.0       3.0       2
# 583           flat         sector 37d      2.0       2.0       3
# 584           flat          sector 79      3.0       4.0      3+
# 585           flat          sector 95      3.0       2.0       2
# 586          house         sector 109      4.0       6.0      3+
# 587           flat          sector 67      3.0       3.0       3
# 588          house          sector 17      4.0       4.0      3+
# 589           flat          sector 33      3.0       2.0      3+
# 590           flat          sector 71      3.0       3.0      3+
# 591           flat          sector 56      3.0       4.0      3+
# 592           flat          sector 85      4.0       4.0       3
# 593           flat          sector 63      4.0       4.0       3
# 594           flat          sector 37      3.0       3.0       3
# 595           flat          sector 56      4.0       3.0      3+
# 596          house          sector 92      4.0       4.0       3
# 597           flat          sector 92      3.0       3.0       2
# 598           flat          sector 56      4.0       4.0      3+
# 599           flat          sector 41      3.0       3.0       2
# 600           flat          sector 49      3.0       4.0       3
# 601          house         sector 109      7.0       6.0       3
# 602           flat          sector 72      4.0       5.0      3+
# 603          house          sector 55      4.0       4.0      3+
# 604           flat          sector 89      2.0       3.0       2
# 605           flat          sector 28      3.0       4.0      3+
# 606           flat         sector 88a      2.0       2.0       1
# 607           flat         sohna road      2.0       2.0       2
# 608          house         sector 110      1.0       1.0       0
# 609           flat          sector 67      3.0       3.0      3+
# 610           flat          sector 67      3.0       4.0       3
# 611           flat          sector 33      3.0       3.0       2
# 612           flat            manesar      3.0       4.0       2
# 613           flat          sector 89      3.0       2.0       3
# 614           flat         sector 67a      2.0       2.0       2
# 615           flat          sector 69      3.0       3.0       2
# 616           flat            manesar      3.0       2.0      3+
# 617          house          sector 43      1.0       1.0       0
# 618           flat          sector 71      3.0       3.0       3
# 619           flat          sector 33      3.0       2.0      3+
# 620          house          sector 25      6.0       7.0      3+
# 621          house          sector 31      5.0       5.0      3+
# 622          house         sector 70a      2.0       3.0      3+
# 623           flat         sohna road      2.0       2.0       1
# 624           flat          sector 90      3.0       3.0      3+
# 625           flat          sector 14      3.0       4.0      3+
# 626           flat          sector 89      2.0       2.0       2
# 627           flat          sector 79      3.0       4.0       2
# 628           flat          sector 81      3.0       3.0      3+
# 629           flat          sector 90      4.0       4.0      3+
# 630          house          sector 43      4.0       4.0      3+
# 631           flat          sector 61      3.0       3.0       3
# 632           flat          sector 99      2.0       2.0       2
# 633           flat          sector 90      2.0       2.0       3
# 634           flat         sector 106      4.0       3.0       3
# 635          house         sector 109      4.0       4.0       2
# 636           flat          sector 90      3.0       3.0      3+
# 637          house           sector 3      1.0       1.0       0
# 638           flat          sector 99      2.0       2.0       1
# 639           flat         sector 112      3.0       3.0       2
# 640           flat          sector 74      2.0       2.0      3+
# 641          house           sector 4      2.0       2.0       1
# 642           flat          sector 72      4.0       4.0      3+
# 643          house           sector 2      3.0       9.0      3+
# 644           flat         sector 110      3.0       3.0      3+
# 645          house           sector 6      2.0       2.0       0
# 646           flat            manesar      3.0       4.0       3
# 647          house           sector 2      4.0       5.0       2
# 648           flat         sector 107      2.0       2.0      3+
# 649           flat          sector 90      3.0       3.0       3
# 650          house          sector 50      4.0       4.0       2
# 651          house          sector 50      5.0       6.0      3+
# 652           flat          sector 86      3.0       2.0       1
# 653           flat          sector 65      3.0       3.0       3
# 654           flat          sector 86      3.0       3.0       3
# 655           flat          sector 52      4.0       4.0      3+
# 656           flat          sector 81      3.0       2.0      3+
# 657           flat          sector 92      3.0       2.0       2
# 658           flat          sector 83      2.0       2.0       2
# 659           flat          sector 85      3.0       3.0       3
# 660          house          sector 48      4.0       4.0       3
# 661           flat         sector 102      3.0       3.0       2
# 662           flat          sector 85      2.0       2.0       3
# 663          house          sector 46      4.0       4.0       2
# 664          house          sector 83      3.0       3.0      3+
# 665           flat          sector 95      2.0       2.0       2
# 666           flat         sector 102      2.0       2.0       2
# 667           flat         sohna road      2.0       2.0       1
# 668           flat          sector 70      6.0       7.0      3+
# 669          house           sector 5      2.0       1.0       0
# 670           flat          sector 33      2.0       2.0       2
# 671           flat          sector 74      3.0       3.0       3
# 672           flat          sector 77      3.0       3.0      3+
# 673           flat          sector 33      2.0       2.0       0
# 674           flat          sector 36      3.0       2.0       3
# 675          house          sector 12      3.0       3.0       0
# 676           flat          sector 69      3.0       3.0       2
# 677           flat         sohna road      1.0       1.0       1
# 678           flat          sector 65      3.0       3.0       3
# 679           flat         sector 88a      3.0       3.0      3+
# 680           flat          sector 69      2.0       2.0       1
# 681           flat          sector 95      2.0       2.0       1
# 682           flat          sector 21      2.0       2.0       2
# 683           flat          sector 43      4.0       5.0       2
# 684          house          sector 26      5.0       7.0      3+
# 685           flat          sector 37      2.0       3.0       3
# 686           flat  dwarka expressway      3.0       3.0      3+
# 687           flat         sohna road      2.0       2.0       2
# 688          house           sector 2      4.0       4.0       1
# 689           flat          sector 65      3.0       4.0       3
# 690           flat          sector 95      1.0       1.0       1
# 691           flat          sector 83      1.0       1.0       0
# 692           flat          sector 66      3.0       4.0       3
# 693          house           sector 7      3.0       3.0       2
# 694          house         sohna road      2.0       3.0       2
# 695          house         sector 108      5.0       4.0      3+
# 696           flat          sector 79      2.0       2.0       2
# 697           flat          sector 82      3.0       3.0      3+
# 698           flat          sector 72      4.0       4.0      3+
# 699          house          sector 38      6.0       6.0      3+
# 700           flat          sector 68      2.0       2.0       3
# 701           flat          sector 86      3.0       3.0       1
# 702           flat          sector 89      2.0       3.0       3
# 703           flat         sohna road      3.0       2.0       2
# ...
# 3258     unfurnished             Low     High Floor
# 3259     unfurnished          Medium      Mid Floor
# 3260  semi-furnished          Medium      Mid Floor
# 3261       furnished            High      Mid Floor
# 3262     unfurnished          Medium      Mid Floor
# 3263     unfurnished          Medium     High Floor
# 3264       furnished            High     High Floor
# 3265     unfurnished          Medium     High Floor
# 3266     unfurnished             Low      Mid Floor
# 3267     unfurnished             Low     High Floor
# 3268     unfurnished            High      Mid Floor
# 3269     unfurnished          Medium     High Floor
# 3270       furnished             Low     High Floor
# 3271     unfurnished             Low     High Floor
# 3272  semi-furnished             Low      Mid Floor
# 3273     unfurnished             Low      Mid Floor
# 3274  semi-furnished             Low      Mid Floor
# 3275     unfurnished             Low      Mid Floor
# 3276     unfurnished             Low      Low Floor
# 3277     unfurnished          Medium      Mid Floor
# 3278     unfurnished             Low     High Floor
# 3279     unfurnished             Low      Low Floor
# 3280     unfurnished             Low     High Floor
# 3281     unfurnished             Low      Low Floor
# 3282     unfurnished             Low      Low Floor
# 3283  semi-furnished             Low      Low Floor
# 3284     unfurnished             Low      Mid Floor
# 3285     unfurnished            High      Mid Floor
# 3286     unfurnished          Medium      Mid Floor
# 3287     unfurnished             Low      Low Floor
# 3288  semi-furnished            High     High Floor
# 3289  semi-furnished            High      Mid Floor
# 3290     unfurnished             Low     High Floor
# 3291  semi-furnished            High     High Floor
# 3292     unfurnished          Medium      Mid Floor
# 3293  semi-furnished            High      Mid Floor
# 3294  semi-furnished            High      Mid Floor
# 3295     unfurnished          Medium     High Floor
# 3296  semi-furnished             Low     High Floor
# 3297     unfurnished             Low      Low Floor
# 3298     unfurnished             Low      Low Floor
# 3299  semi-furnished            High      Mid Floor
# 3300     unfurnished          Medium      Low Floor
# 3301     unfurnished             Low      Mid Floor
# 3302  semi-furnished            High     High Floor
# 3303     unfurnished             Low      Low Floor
# 3304     unfurnished          Medium     High Floor
# 3305     unfurnished            High     High Floor
# 3306     unfurnished             Low      Low Floor
# 3307       furnished             Low     High Floor
# 3308     unfurnished          Medium     High Floor
# 3309  semi-furnished            High      Mid Floor
# 3310     unfurnished             Low      Mid Floor
# 3311     unfurnished          Medium     High Floor
# 3312     unfurnished             Low      Low Floor
# 3313  semi-furnished             Low      Low Floor
# 3314     unfurnished             Low      Mid Floor
# 3315     unfurnished          Medium     High Floor
# 3316     unfurnished          Medium      Mid Floor
# 3317  semi-furnished             Low      Mid Floor
# 3318  semi-furnished          Medium      Mid Floor
# 3319  semi-furnished          Medium      Mid Floor
# 3320       furnished             Low      Low Floor
# 3321       furnished             Low      Mid Floor
# 3322     unfurnished             Low      Mid Floor
# 3323     unfurnished             Low      Low Floor
# 3324  semi-furnished            High      Mid Floor
# 3325     unfurnished          Medium      Mid Floor
# 3326     unfurnished             Low      Mid Floor
# 3327  semi-furnished          Medium      Mid Floor
# 3328  semi-furnished             Low     High Floor
# 3329     unfurnished             Low      Mid Floor
# 3330     unfurnished            High     High Floor
# 3331     unfurnished          Medium     High Floor
# 3332     unfurnished             Low      Low Floor
# 3333     unfurnished             Low      Mid Floor
# 3334  semi-furnished             Low      Mid Floor
# 3335     unfurnished          Medium      Mid Floor
# 3336     unfurnished          Medium      Low Floor
# 3337  semi-furnished             Low      Low Floor
# 3338     unfurnished          Medium      Mid Floor
# 3339     unfurnished          Medium      Mid Floor
# 3340  semi-furnished            High     High Floor
# 3341     unfurnished            High     High Floor
# 3342     unfurnished          Medium      Mid Floor
# 3343       furnished          Medium     High Floor
# 3344  semi-furnished            High     High Floor
# 3345     unfurnished             Low     High Floor
# 3346       furnished             Low      Low Floor
# 3347     unfurnished          Medium      Mid Floor
# 3348     unfurnished             Low      Mid Floor
# 3349  semi-furnished          Medium      Low Floor
# 3350     unfurnished          Medium     High Floor
# 3351     unfurnished          Medium     High Floor
# 3352     unfurnished          Medium     High Floor
# 3353  semi-furnished             Low      Mid Floor
# 3354     unfurnished          Medium      Mid Floor
# 3355  semi-furnished          Medium      Low Floor
# 3356  semi-furnished            High     High Floor
# 3357     unfurnished          Medium      Mid Floor
# 3358     unfurnished            High     High Floor
# 3359     unfurnished          Medium     High Floor
# 3360       furnished             Low      Mid Floor
# 3361     unfurnished             Low      Mid Floor
# 3362     unfurnished          Medium     High Floor
# 3363     unfurnished          Medium      Mid Floor
# 3364     unfurnished             Low      Low Floor
# 3365     unfurnished          Medium     High Floor
# 3366     unfurnished            High      Mid Floor
# 3367     unfurnished          Medium      Mid Floor
# 3368       furnished          Medium      Mid Floor
# 3369     unfurnished             Low      Low Floor
# 3370     unfurnished          Medium      Mid Floor
# 3371  semi-furnished             Low      Low Floor
# 3372     unfurnished             Low      Low Floor
# 3373  semi-furnished             Low     High Floor
# 3374  semi-furnished          Medium      Mid Floor
# 3375     unfurnished          Medium     High Floor
# 3376  semi-furnished            High     High Floor
# 3377  semi-furnished             Low      Mid Floor
# 3378     unfurnished          Medium      Mid Floor
# 3379     unfurnished          Medium      Low Floor
# 3380     unfurnished          Medium     High Floor
# 3381     unfurnished             Low      Mid Floor
# 3382     unfurnished             Low      Mid Floor
# 3383     unfurnished             Low      Low Floor
# 3384     unfurnished             Low      Mid Floor
# 3385     unfurnished          Medium      Mid Floor
# 3386     unfurnished             Low      Low Floor
# 3387       furnished             Low      Mid Floor
# 3388     unfurnished             Low      Low Floor
# 3389     unfurnished             Low      Mid Floor
# 3390  semi-furnished             Low      Low Floor
# 3391     unfurnished             Low      Mid Floor
# 3392     unfurnished             Low      Mid Floor
# 3393       furnished            High     High Floor
# 3394     unfurnished            High      Mid Floor
# 3395  semi-furnished             Low      Mid Floor
# 3396     unfurnished            High     High Floor
# 3397     unfurnished          Medium      Low Floor
# 3398  semi-furnished          Medium      Mid Floor
# 3399  semi-furnished          Medium     High Floor
# 3400     unfurnished          Medium      Mid Floor
# 3401  semi-furnished             Low      Mid Floor
# 3402     unfurnished             Low      Mid Floor
# 3403  semi-furnished          Medium     High Floor
# 3404  semi-furnished            High      Low Floor
# 3405     unfurnished             Low      Mid Floor
# 3406     unfurnished            High      Low Floor
# 3407     unfurnished             Low     High Floor
# 3408     unfurnished             Low      Mid Floor
# 3409     unfurnished             Low      Low Floor
# 3410     unfurnished             Low      Low Floor
# 3411     unfurnished          Medium      Mid Floor
# 3412     unfurnished             Low      Mid Floor
# 3413     unfurnished          Medium      Mid Floor
# 3414  semi-furnished          Medium      Mid Floor
# 3415     unfurnished            High      Mid Floor
# 3416     unfurnished          Medium      Low Floor
# 3417     unfurnished          Medium      Mid Floor
# 3418     unfurnished            High      Mid Floor
# 3419  semi-furnished          Medium      Mid Floor
# 3420  semi-furnished             Low      Mid Floor
# 3421     unfurnished             Low      Low Floor
# 3422  semi-furnished             Low     High Floor
# 3423     unfurnished          Medium      Mid Floor
# 3424       furnished            High     High Floor
# 3425     unfurnished          Medium      Low Floor
# 3426  semi-furnished          Medium      Mid Floor
# 3427       furnished            High      Low Floor
# 3428     unfurnished             Low      Mid Floor
# 3429     unfurnished             Low     High Floor
# 3430     unfurnished             Low     High Floor
# 3431     unfurnished          Medium      Low Floor
# 3432     unfurnished          Medium      Mid Floor
# 3433  semi-furnished          Medium      Mid Floor
# 3434     unfurnished             Low     High Floor
# 3435     unfurnished             Low      Mid Floor
# 3436     unfurnished          Medium     High Floor
# 3437     unfurnished             Low      Mid Floor
# 3438     unfurnished          Medium      Low Floor
# 3439  semi-furnished          Medium     High Floor
# 3440     unfurnished             Low      Low Floor
# 3441  semi-furnished          Medium      Mid Floor
# 3442     unfurnished          Medium      Mid Floor
# 3443  semi-furnished          Medium      Low Floor
# 3444     unfurnished          Medium     High Floor
# 3445     unfurnished             Low      Mid Floor
# 3446     unfurnished             Low      Low Floor
# 3447       furnished          Medium      Mid Floor
# 3448     unfurnished          Medium      Mid Floor
# 3449     unfurnished          Medium     High Floor
# 3450     unfurnished             Low      Mid Floor
# 3451  semi-furnished          Medium     High Floor
# 3452     unfurnished             Low      Mid Floor
# 3453  semi-furnished             Low      Low Floor
# 3454  semi-furnished          Medium     High Floor
# 3455  semi-furnished            High      Mid Floor
# 3456     unfurnished             Low      Mid Floor
# 3457     unfurnished          Medium      Mid Floor
# 3458     unfurnished          Medium      Low Floor
# 3459  semi-furnished          Medium      Low Floor
# 3460       furnished            High     High Floor
# 3461  semi-furnished             Low      Mid Floor
# 3462     unfurnished            High     High Floor
# 3463       furnished            High      Low Floor
# 3464     unfurnished          Medium      Mid Floor
# 3465  semi-furnished          Medium      Mid Floor
# 3466  semi-furnished             Low      Mid Floor
# 3467  semi-furnished            High      Mid Floor
# 3468     unfurnished             Low      Low Floor
# 3469     unfurnished          Medium      Mid Floor
# 3470  semi-furnished             Low      Mid Floor
# 3471     unfurnished             Low      Low Floor
# 3472     unfurnished             Low      Mid Floor
# 3473     unfurnished             Low      Low Floor
# 3474     unfurnished          Medium     High Floor
# 3475     unfurnished          Medium     High Floor
# 3476  semi-furnished             Low     High Floor
# 3477     unfurnished             Low      Mid Floor
# 3478     unfurnished          Medium      Mid Floor
# 3479  semi-furnished             Low      Low Floor
# 3480  semi-furnished          Medium      Low Floor
# 3481  semi-furnished          Medium     High Floor
# 3482     unfurnished             Low      Mid Floor
# 3483     unfurnished            High      Mid Floor
# 3484       furnished            High      Mid Floor
# 3485     unfurnished            High      Mid Floor
# 3486     unfurnished             Low      Mid Floor
# 3487     unfurnished             Low      Mid Floor
# 3488     unfurnished          Medium     High Floor
# 3489  semi-furnished          Medium     High Floor
# 3490     unfurnished             Low      Mid Floor
# 3491  semi-furnished             Low      Mid Floor
# 3492     unfurnished             Low      Mid Floor
# 3493     unfurnished          Medium     High Floor
# 3494     unfurnished             Low      Mid Floor
# 3495     unfurnished             Low      Mid Floor
# 3496     unfurnished             Low      Low Floor
# 3497     unfurnished          Medium      Mid Floor
# 3498     unfurnished            High      Mid Floor
# 3499     unfurnished          Medium      Mid Floor
# 3500     unfurnished             Low      Low Floor
# 3501     unfurnished          Medium      Mid Floor
# 3502     unfurnished          Medium      Mid Floor
# 3503     unfurnished          Medium      Mid Floor
# 3504  semi-furnished          Medium     High Floor
# 3505     unfurnished          Medium      Mid Floor
# 3506     unfurnished            High     High Floor
# 3507     unfurnished             Low      Low Floor
# 3508     unfurnished          Medium      Mid Floor
# 3509     unfurnished          Medium     High Floor
# 3510     unfurnished            High      Mid Floor
# 3511     unfurnished             Low      Low Floor
# 3512     unfurnished             Low      Mid Floor
# 3513     unfurnished          Medium     High Floor
# 3514     unfurnished             Low      Mid Floor
# 3515     unfurnished          Medium      Mid Floor
# 3516  semi-furnished             Low      Low Floor
# 3517     unfurnished             Low      Mid Floor
# 3518     unfurnished             Low      Mid Floor
# 3519     unfurnished             Low      Mid Floor
# 3520     unfurnished          Medium      Mid Floor
# 3521     unfurnished             Low      Mid Floor
# 3522  semi-furnished          Medium      Mid Floor
# 3523     unfurnished             Low      Low Floor
# 3524  semi-furnished            High      Mid Floor
# 3525  semi-furnished            High      Mid Floor
# 3526     unfurnished             Low     High Floor
# 3527     unfurnished             Low     High Floor
# 3528  semi-furnished             Low      Mid Floor
# 3529     unfurnished          Medium     High Floor
# 3530     unfurnished          Medium      Mid Floor
# 3531     unfurnished             Low     High Floor
# 3532     unfurnished             Low     High Floor
# 3533     unfurnished          Medium     High Floor
# 3534     unfurnished             Low      Low Floor
# 3535  semi-furnished          Medium     High Floor
# 3536     unfurnished          Medium      Low Floor
# 3537     unfurnished             Low      Mid Floor
# 3538     unfurnished             Low      Mid Floor
# 3539     unfurnished          Medium      Low Floor
# 3540     unfurnished             Low     High Floor
# 3541     unfurnished             Low      Mid Floor
# 3542     unfurnished          Medium      Mid Floor
# 3543  semi-furnished             Low     High Floor
# 3544     unfurnished             Low      Low Floor
# 3545       furnished          Medium      Mid Floor
# 3546     unfurnished          Medium      Mid Floor
# 3547     unfurnished            High      Low Floor
# 3548     unfurnished             Low      Low Floor
# 3549     unfurnished          Medium      Mid Floor
# 3550     unfurnished            High      Low Floor
# 3551  semi-furnished          Medium      Mid Floor
# 3552     unfurnished          Medium      Mid Floor
# 3553  semi-furnished          Medium     High Floor

# %% [markdown]
# # **Trying out the predictions**

# %%
X.columns
# Out:
# Index(['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
#        'agePossession', 'built_up_area', 'servant room', 'store room',
#        'furnishing_type', 'luxury_category', 'floor_category'],
#       dtype='object')

# %%
X.iloc[0].values
# Out:
# array(['flat', 'sector 36', np.float64(3.0), np.float64(2.0), '2',
#        'New Property', np.float64(850.0), np.float64(0.0),
#        np.float64(0.0), 'unfurnished', 'Low', 'Low Floor'], dtype=object)

# %%
data = [['house', 'sector 102', 3, 1, '3+', 'New Property', 1700, 0, 0, 'furnished', 'Low', 'Low Floor']]
columns = ['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
       'agePossession', 'built_up_area', 'servant room', 'store room',
       'furnishing_type', 'luxury_category', 'floor_category']

# Convert to DataFrame
one_df = pd.DataFrame(data, columns=columns)

one_df
# Out:
#   property_type      sector  bedRoom  bathroom balcony agePossession  \
# 0         house  sector 102        3         1      3+  New Property
#
#    built_up_area  servant room  store room furnishing_type luxury_category  \
# 0           1700             0           0       furnished             Low
#
#   floor_category
# 0      Low Floor

# %%
np.expm1(pipeline.predict(one_df))
# Out:
# array([2.30524908])
